# %% [markdown]
# # Obtaining Our Data - Lab

# %% [markdown]
# ## Introduction
# In this lab you'll practice your munging and transforming skills in order to load in your data to solve a regression problem.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand the ETL process and the steps it consists of
# * Understand the challenges of working with data from multiple sources

# %% [markdown]
# ## Task Description
#
# Your boss gives you a general description of some of the datasets at your disposal for analyzing weekly store sales. They're eventually looking for you to build a model to help determine what factors impact sales, and model future sales forecasting for business planning.
#
# Most of the properietary store data sits in the company sql database, accessible by all managers and above. The database is called **Walmart.db** Your boss provides you with the following basic schema:
#
# <img src='db_schema.jpg' width=500>
#
# She then tells you that she's put together a second dataset on general economy statistics for the various dates that she would also like you to incorporate in your analysis. That data, she says, is stored in a file **economy_data.csv**.
#
# As a first step in creating your model for providing recommendations and projections, load and synthesize these disperate datasets into a singular unified DataFrame. Then save your results to a file **Merged_Store_Data.csv**.
#
# Make sure you check the various data types and merge appropriately.

# %% [markdown]
# # Import Walmart.db Database using SQL

# %% [markdown]
# Store Walmart.db within a dataframe

# %%
# Your code here
import sqlite3
import pandas as pd

#connection
con = sqlite3.connect('Walmart.db')
#cursor
cur = con.cursor()
#data
cur.execute('''SELECT * from Sales join store_details using(Store);''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]

# %% [markdown]
# ### Explore Walmart.db dataframe

# %%
print(df.shape)
df.head()
# Out:
# (452192, 7)
#    Store  Dept        Date  Weekly_Sales IsHoliday Type    Size
# 0      1     1  2010-02-05      24924.50     False    A  151315
# 1      1     1  2010-02-12      46039.49      True    A  151315
# 2      1     1  2010-02-19      41595.55     False    A  151315
# 3      1     1  2010-02-26      19403.54     False    A  151315
# 4      1     1  2010-03-05      21827.90     False    A  151315

# %%
print('There are ' + str(df.shape[0]) + ' samples and 7 features on this database')
# Out:
# There are 452192 samples and 7 features on this database

# %%
print('There are ' + str(len(df.Date.unique())) + ' unique dates.')
print('There are ' + str(len(df.Store.unique())) + ' unique stores.')
# Out:
# There are 143 unique dates.
# There are 45 unique stores.

# %%
print('Earliest sample date: ' + str(df.Date.min()))
print('Latest sample date: ' + str(df.Date.max()))
# Out:
# Earliest sample date: 2010-02-05
# Latest sample date: 2012-10-26

# %% [markdown]
# # Import Economy CSV file as Dataframe

# %%
df_econ = pd.read_csv('economy_data.csv')

# %% [markdown]
# ### Explore Economy dataframe

# %%
df_econ.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
print('There are ' + str(df_econ.shape[0]) + ' samples on this dataset.')
# Out:
# There are 8190 samples on this dataset.

# %%
print('There are ' + str(len(df_econ.Date.unique())) + ' unique dates.')
print('There are ' + str(len(df_econ.Store.unique())) + ' unique stores.')
# Out:
# There are 182 unique dates.
# There are 45 unique stores.

# %%
print('Earliest sample date: ' + str(df_econ.Date.min()))
print('Latest sample date: ' + str(df_econ.Date.max()))
# Out:
# Earliest sample date: 2010-02-05
# Latest sample date: 2013-07-26

# %% [markdown]
# ## Finding 1: Sales Data stops on 2012_10_26

# %% [markdown]
# Therefore, we have no use for samples beyond that point in the df_econ dataframe.

# %%
#convert dates to pandas datetime
df_econ['Date'] = pd.to_datetime(df_econ['Date'])

# %%
# delete entries from df_econ beyond 2012_10_26
import datetime
# drop row if Date > 2012_10_26
date = pd.to_datetime('2012-10-26')
df_econ = df_econ[df_econ['Date'] <= date]
df_econ.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8146     45 2012-09-28        64.88       3.997    4556.61      20.64
# 8147     45 2012-10-05        64.89       3.985    5046.74        NaN
# 8148     45 2012-10-12        54.47       4.000    1956.28        NaN
# 8149     45 2012-10-19        56.47       3.969    2004.02        NaN
# 8150     45 2012-10-26        58.85       3.882    4018.91      58.08
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 8146       1.50    1601.01    3288.25  192.013558         8.684      False
# 8147      18.82    2253.43    2340.01  192.170412         8.667      False
# 8148       7.89     599.32    3990.54  192.327265         8.667      False
# 8149       3.18     437.73    1537.49  192.330854         8.667      False
# 8150     100.00     211.94     858.33  192.308899         8.667      False

# %%
df_econ.shape
# Out:
# (6435, 12)

# %%
# Let's check how many unique dates are now in the df_econ dataframe
len(df_econ['Date'].unique())
# Out:
# 143

# %% [markdown]
# Success! Now we have 143 unique dates that hopefully coincide with the dates in the sales dataframe. Let's check that.

# %%
# first convert dates to datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
# check for NaN values in various columns
na = []
for column in df.columns:
    na.append(sum(df[column].isna()))
na
# Out:
# [0, 0, 0, 0, 0, 0, 0]

# %%
# No NaN values in df

# %%
na = []
for column in df_econ.columns:
    na.append(sum(df_econ[column].isna()))
na
# Out:
# [0, 0, 0, 0, 4155, 4798, 4389, 4470, 4140, 0, 0, 0]

# %%
df_econ.shape
# Out:
# (6435, 12)

# %% [markdown]
# Although these NANs in Markdowns are a great portion, their presence may
# be valuable (lack of a markdown may be related with less sales, for instance)

# %%
df.shape, df_econ.shape
# Out:
# ((452192, 7), (6435, 12))

# %%
df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales IsHoliday Type    Size
# 0      1     1 2010-02-05      24924.50     False    A  151315
# 1      1     1 2010-02-12      46039.49      True    A  151315
# 2      1     1 2010-02-19      41595.55     False    A  151315
# 3      1     1 2010-02-26      19403.54     False    A  151315
# 4      1     1 2010-03-05      21827.90     False    A  151315

# %%
df_econ.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-02-12        38.51       2.548        NaN        NaN        NaN
# 2      1 2010-02-19        39.93       2.514        NaN        NaN        NaN
# 3      1 2010-02-26        46.63       2.561        NaN        NaN        NaN
# 4      1 2010-03-05        46.50       2.625        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN  211.096358         8.106       True
# 1        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN  211.289143         8.106       True
# 3        NaN        NaN  211.319643         8.106       True
# 4        NaN        NaN  211.350143         8.106       True

# %%
df.IsHoliday = df.IsHoliday.astype(bool)
df_econ.IsHoliday = df.IsHoliday.astype(bool)

# %%
merged = df.merge(df_econ)

merged
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoli
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 1             42.31       2.572        NaN        NaN        NaN        NaN
# 2             42.31       2.572        NaN        NaN        NaN        NaN
# 3             42.31       2.572        NaN        NaN        NaN        NaN
# 4             42.31       2.572        NaN        NaN        NaN        NaN
# 5             42.31       2.572        NaN        NaN        NaN        NaN
# 6             42.31       2.572        NaN        NaN        NaN        NaN
# 7             42.31       2.572        NaN        NaN        NaN        NaN
# 8             42.31       2.572        NaN        NaN        NaN        NaN
# 9             42.31       2.572        NaN        NaN        NaN        NaN
# 10            42.31       2.572        NaN        NaN        NaN        NaN
# 11            42.31       2.572        NaN        NaN        NaN        NaN
# 12            42.31       2.572        NaN        NaN        NaN        NaN
# 13            42.31       2.572        NaN        NaN        NaN        NaN
# 14            42.31       2.572        NaN        NaN        NaN        NaN
# 15            42.31       2.572        NaN        NaN        NaN        NaN
# 16            42.31       2.572        NaN        NaN        NaN        NaN
# 17            42.31       2.572        NaN        NaN        NaN        NaN
# 18            42.31       2.572        NaN        NaN        NaN        NaN
# 19            42.31       2.572        NaN        NaN        NaN        NaN
# 20            42.31       2.572        NaN        NaN        NaN        NaN
# 21            42.31       2.572        NaN        NaN        NaN        NaN
# 22            42.31       2.572        NaN        NaN        NaN        NaN
# 23            42.31       2.572        NaN        NaN        NaN        NaN
# 24            42.31       2.572        NaN        NaN        NaN        NaN
# 25            42.31       2.572        NaN        NaN        NaN        NaN
# 26            42.31       2.572        NaN        NaN        NaN        NaN
# 27            42.31       2.572        NaN        NaN        NaN        NaN
# 28            42.31       2.572        NaN        NaN        NaN        NaN
# 29            42.31       2.572        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 452162        58.85       3.882    4018.91      58.08      100.0     211.94
# 452163        58.85       3.882    4018.91      58.08      100.0     211.94
# 452164        58.85       3.882    4018.91      58.08      100.0     211.94
# 452165        58.85       3.882    4018.91      58.08      100.0     211.94
# 452166        58.85       3.882    4018.91      58.08      100.0     211.94
# 452167        58.85       3.882    4018.91      58.08      100.0     211.94
# 452168        58.85       3.882    4018.91      58.08      100.0     211.94
# 452169        58.85       3.882    4018.91      58.08      100.0     211.94
# 452170        58.85       3.882    4018.91      58.08      100.0     211.94
# 452171        58.85       3.882    4018.91      58.08      100.0     211.94
# 452172        58.85       3.882    4018.91      58.08      100.0     211.94
# 452173        58.85       3.882    4018.91      58.08      100.0     211.94
# 452174        58.85       3.882    4018.91      58.08      100.0     211.94
# 452175        58.85       3.882    4018.91      58.08      100.0     211.94
# 452176        58.85       3.882    4018.91      58.08      100.0     211.94
# 452177        58.85       3.882    4018.91      58.08      100.0     211.94
# 452178        58.85       3.882    4018.91      58.08      100.0     211.94
# 452179        58.85       3.882    4018.91      58.08      100.0     211.94
# 452180        58.85       3.882    4018.91      58.08      100.0     211.94
# 452181        58.85       3.882    4018.91      58.08      100.0     211.94
# 452182        58.85       3.882    4018.91      58.08      100.0     211.94
# 452183        58.85       3.882    4018.91      58.08      100.0     211.94
# 452184        58.85       3.882    4018.91      58.08      100.0     211.94
# 452185        58.85       3.882    4018.91      58.08      100.0     211.94
# 452186        58.85       3.882    4018.91      58.08      100.0     211.94
# 452187        58.85       3.882    4018.91      58.08      100.0     211.94
# 452188        58.85       3.882    4018.91      58.08      100.0     211.94
# 452189        58.85       3.882    4018.91      58.08      100.0     211.94
# 452190        58.85       3.882    4018.91      58.08      100.0     211.94
# 452191        58.85       3.882    4018.91      58.08      100.0     211.94
#
#         MarkDown5         CPI  Unemployment
# 0             NaN  211.096358         8.106
# 1             NaN  211.096358         8.106
# 2             NaN  211.096358         8.106
# 3             NaN  211.096358         8.106
# 4             NaN  211.096358         8.106
# 5             NaN  211.096358         8.106
# 6             NaN  211.096358         8.106
# 7             NaN  211.096358         8.106
# 8             NaN  211.096358         8.106
# 9             NaN  211.096358         8.106
# 10            NaN  211.096358         8.106
# 11            NaN  211.096358         8.106
# 12            NaN  211.096358         8.106
# 13            NaN  211.096358         8.106
# 14            NaN  211.096358         8.106
# 15            NaN  211.096358         8.106
# 16            NaN  211.096358         8.106
# 17            NaN  211.096358         8.106
# 18            NaN  211.096358         8.106
# 19            NaN  211.096358         8.106
# 20            NaN  211.096358         8.106
# 21            NaN  211.096358         8.106
# 22            NaN  211.096358         8.106
# 23            NaN  211.096358         8.106
# 24            NaN  211.096358         8.106
# 25            NaN  211.096358         8.106
# 26            NaN  211.096358         8.106
# 27            NaN  211.096358         8.106
# 28            NaN  211.096358         8.106
# 29            NaN  211.096358         8.106
# ...           ...         ...           ...
# 452162     858.33  192.308899         8.667
# 452163     858.33  192.308899         8.667
# 452164     858.33  192.308899         8.667
# 452165     858.33  192.308899         8.667
# 452166     858.33  192.308899         8.667
# 452167     858.33  192.308899         8.667
# 452168     858.33  192.308899         8.667
# 452169     858.33  192.308899         8.667
# 452170     858.33  192.308899         8.667
# 452171     858.33  192.308899         8.667
# 452172     858.33  192.308899         8.667
# 452173     858.33  192.308899         8.667
# 452174     858.33  192.308899         8.667
# 452175     858.33  192.308899         8.667
# 452176     858.33  192.308899         8.667
# 452177     858.33  192.308899         8.667
# 452178     858.33  192.308899         8.667
# 452179     858.33  192.308899         8.667
# 452180     858.33  192.308899         8.667
# 452181     858.33  192.308899         8.667
# 452182     858.33  192.308899         8.667
# 452183     858.33  192.308899         8.667
# 452184     858.33  192.308899         8.667
# 452185     858.33  192.308899         8.667
# 452186     858.33  192.308899         8.667
# 452187     858.33  192.308899         8.667
# 452188     858.33  192.308899         8.667
# 452189     858.33  192.308899         8.667
# 452190     858.33  192.308899         8.667
# 452191     858.33  192.308899         8.667
#
# [452192 rows x 16 columns]

# %%
merged.shape
# Out:
# (452192, 16)

# %%
merged.to_csv('Merged_Store_Data.csv',index=False)

# %% [markdown]
# ## Summary
# Nice work! You're working more and more independently through the workflow, and ensuring data integrity!
